# %% [markdown]
# # Variable Assignment
#
# ## Rules for variable names
# * names can not start with a number
# * names can not contain spaces, use _ intead
# * names can not contain any of these symbols:
#
#       :'",<>/?|\!@#%^&*~-+
#
# * it's considered best practice ([PEP8](https://www.python.org/dev/peps/pep-0008/#function-and-variable-names)) that names are lowercase with underscores
# * avoid using Python built-in keywords like `list` and `str`
# * avoid using the single characters `l` (lowercase letter el), `O` (uppercase letter oh) and `I` (uppercase letter eye) as they can be confused with `1` and `0`

# %% [markdown]
# ## Dynamic Typing
#
# Python uses *dynamic typing*, meaning you can reassign variables to different data types. This makes Python very flexible in assigning data types; it differs from other languages that are *statically typed*.

# %%
my_dogs = 2

# %%
type(my_dogs)

# %%
my_dogs = 'Sammy and Fido'

# %%
my_dogs

# %% [markdown]
# ### Pros and Cons of Dynamic Typing
# #### Pros of Dynamic Typing
# * very easy to work with
# * faster development time
#
# #### Cons of Dynamic Typing
# * may result in unexpected bugs!
# * you need to be aware of `type()`

# %% [markdown]
# ## Assigning Variables
# Variable assignment follows `name = object`, where a single equals sign `=` is an *assignment operator*

# %%
a = 5

# %%
a

# %% [markdown]
# Here we assigned the integer object `5` to the variable name `a`.<br>Let's assign `a` to something else:

# %%
a = 10

# %%
a

# %% [markdown]
# You can now use `a` in place of the number `10`:

# %%
a = a + a

# %% [markdown]
# ## Reassigning Variables
# Python lets you reassign variables with a reference to the same object.

# %%
a = a + 10

# %%
a

# %% [markdown]
# There's actually a shortcut for this. Python lets you add, subtract, multiply and divide numbers with reassignment using `+=`, `-=`, `*=`, and `/=`.

# %%
a += 10

# %%
a

# %%
a *= 2

# %%
a

# %% [markdown]
# ## Determining variable type with `type()`
# You can check what type of object is assigned to a variable using Python's built-in `type()` function. Common data types include:
# * **int** (for integer)
# * **float**
# * **str** (for string)
# * **list**
# * **tuple**
# * **dict** (for dictionary)
# * **set**
# * **bool** (for Boolean True/False)

# %%
type(a)

# %%
a = (1,2)

# %%
type(a)

# %% [markdown]
# ## Simple Exercise
# This shows how variables make calculations more readable and easier to follow.

# %%
my_income = 100
tax_rate = 0.2
my_taxes = my_income * tax_rate

# %%
my_taxes

# %% [markdown]
# Now let's try taking input from the user to calculate taxes. We want something that will look like this:

# %% [raw]
# Please provide your income.
# Income: 100
# Please provide your tax rate:
# Tax rate: 0.2
# Your taxes are 20.

# %% [markdown]
# We can achieve this using the print() and input() functions

# %% [markdown]
# What happened? We got an error? As we feared, we've made the mistake of trying to multiply strings together...
# Perhaps without realizing it, our input function were not numbers like floats and integers, but strings.
# This is where "re-casting" comes into play

# %% [markdown]
# Great! You should now understand the basics of variable assignment and reassignment in Python.<br>Up next, we'll learn about strings!
